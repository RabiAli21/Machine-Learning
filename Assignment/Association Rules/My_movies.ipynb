# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori,association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
data = pd.read_csv("my_movies.csv")
data
# Out:
#               V1             V2             V3          V4     V5  ...  LOTR2  Harry Potter2  LOTR  Braveheart  Green Mile
# 0    Sixth Sense          LOTR1  Harry Potter1  Green Mile  LOTR2  ...      1              0     0           0           1
# 1      Gladiator        Patriot     Braveheart         NaN    NaN  ...      0              0     0           1           0
# 2          LOTR1          LOTR2            NaN         NaN    NaN  ...      1              0     0           0           0
# 3      Gladiator        Patriot    Sixth Sense         NaN    NaN  ...      0              0     0           0           0
# 4      Gladiator        Patriot    Sixth Sense         NaN    NaN  ...      0              0     0           0           0
# 5      Gladiator        Patriot    Sixth Sense         NaN    NaN  ...      0              0     0           0           0
# 6  Harry Potter1  Harry Potter2            NaN         NaN    NaN  ...      0              1     0           0           0
# ...

# %%
data = data.iloc[:,5:]

# %% [markdown]
# # Apriori Algorithm

# %%
frequent_itemsets = apriori(data, min_support=0.1, use_colnames=True)
frequent_itemsets
# Out:
# C:\Users\user\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#     support                                           itemsets
# 0       0.6                                      (Sixth Sense)
# 1       0.7                                        (Gladiator)
# 2       0.2                                            (LOTR1)
# 3       0.2                                    (Harry Potter1)
# 4       0.6                                          (Patriot)
# 5       0.2                                            (LOTR2)
# 6       0.1                                    (Harry Potter2)
# 7       0.1                                             (LOTR)
# 8       0.1                                       (Braveheart)
# ...

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0.7)
rules
rules.sort_values('lift',ascending = False).head(10)
# Out:
#                             antecedents                   consequents  ...  conviction  zhangs_metric
# 169                 (Green Mile, LOTR1)  (Sixth Sense, Harry Potter1)  ...         inf            1.0
# 227  (Green Mile, LOTR2, Harry Potter1)          (LOTR1, Sixth Sense)  ...         inf            1.0
# 159              (LOTR2, Harry Potter1)          (LOTR1, Sixth Sense)  ...         inf            1.0
# 183                 (Green Mile, LOTR1)          (LOTR2, Sixth Sense)  ...         inf            1.0
# 184                 (Green Mile, LOTR2)          (LOTR1, Sixth Sense)  ...         inf            1.0
# 185                (LOTR1, Sixth Sense)           (Green Mile, LOTR2)  ...         inf            1.0
# 215              (LOTR2, Harry Potter1)           (Green Mile, LOTR1)  ...         inf            1.0
# 214              (LOTR1, Harry Potter1)           (Green Mile, LOTR2)  ...         inf            1.0
# ...

# %%
rules.shape
# Out:
# (250, 10)

# %%
rules[rules.lift>1]
# Out:
#          antecedents                                      consequents  ...  conviction  zhangs_metric
# 0      (Sixth Sense)                                      (Gladiator)  ...        1.80       0.400000
# 1        (Gladiator)                                    (Sixth Sense)  ...        1.40       0.533333
# 6      (Sixth Sense)                                        (Patriot)  ...        1.20       0.250000
# 7          (Patriot)                                    (Sixth Sense)  ...        1.20       0.250000
# 10     (Sixth Sense)                                           (LOTR)  ...        1.08       1.000000
# ..               ...                                              ...  ...         ...            ...
# 245     (Green Mile)       (LOTR1, Sixth Sense, LOTR2, Harry Potter1)  ...        1.80       1.000000
# 246  (Harry Potter1)          (Green Mile, LOTR1, Sixth Sense, LOTR2)  ...        1.80       1.000000
# ...

# %% [markdown]
# #Try different values of support and confidence

# %%
import warnings
warnings.filterwarnings("ignore")
frequent_itemsets1 = apriori(data, min_support=0.2, use_colnames=True)
frequent_itemsets1
# Out:
#     support                           itemsets
# 0       0.6                      (Sixth Sense)
# 1       0.7                        (Gladiator)
# 2       0.2                            (LOTR1)
# 3       0.2                    (Harry Potter1)
# 4       0.6                          (Patriot)
# 5       0.2                            (LOTR2)
# 6       0.2                       (Green Mile)
# 7       0.5           (Sixth Sense, Gladiator)
# 8       0.4             (Sixth Sense, Patriot)
# 9       0.2          (Green Mile, Sixth Sense)
# 10      0.6               (Patriot, Gladiator)
# 11      0.2                     (LOTR1, LOTR2)
# 12      0.4  (Sixth Sense, Gladiator, Patriot)

# %%
rules1 = association_rules(frequent_itemsets1, metric="lift", min_threshold=0.6)
rules1
# Out:
#                  antecedents               consequents  antecedent support  ...  leverage  conviction  zhangs_metric
# 0              (Sixth Sense)               (Gladiator)                 0.6  ...      0.08         1.8       0.400000
# 1                (Gladiator)             (Sixth Sense)                 0.7  ...      0.08         1.4       0.533333
# 2              (Sixth Sense)                 (Patriot)                 0.6  ...      0.04         1.2       0.250000
# 3                  (Patriot)             (Sixth Sense)                 0.6  ...      0.04         1.2       0.250000
# 4               (Green Mile)             (Sixth Sense)                 0.2  ...      0.08         inf       0.500000
# 5              (Sixth Sense)              (Green Mile)                 0.6  ...      0.08         1.2       1.000000
# 6                  (Patriot)               (Gladiator)                 0.6  ...      0.18         inf       0.750000
# ...

# %%
frequent_itemsets2 = apriori(data, min_support=0.3, use_colnames=True)
frequent_itemsets2
# Out:
#    support                           itemsets
# 0      0.6                      (Sixth Sense)
# 1      0.7                        (Gladiator)
# 2      0.6                          (Patriot)
# 3      0.5           (Sixth Sense, Gladiator)
# 4      0.4             (Sixth Sense, Patriot)
# 5      0.6               (Patriot, Gladiator)
# 6      0.4  (Sixth Sense, Gladiator, Patriot)

# %%
rules2 = association_rules(frequent_itemsets2, metric="lift", min_threshold=0.5)
rules2
# Out:
#                  antecedents               consequents  antecedent support  ...  leverage  conviction  zhangs_metric
# 0              (Sixth Sense)               (Gladiator)                 0.6  ...      0.08         1.8       0.400000
# 1                (Gladiator)             (Sixth Sense)                 0.7  ...      0.08         1.4       0.533333
# 2              (Sixth Sense)                 (Patriot)                 0.6  ...      0.04         1.2       0.250000
# 3                  (Patriot)             (Sixth Sense)                 0.6  ...      0.04         1.2       0.250000
# 4                  (Patriot)               (Gladiator)                 0.6  ...      0.18         inf       0.750000
# 5                (Gladiator)                 (Patriot)                 0.7  ...      0.18         2.8       1.000000
# 6   (Sixth Sense, Gladiator)                 (Patriot)                 0.5  ...      0.10         2.0       0.500000
# ...

# %%
frequent_itemsets3 = apriori(data, min_support=0.4, use_colnames=True)
frequent_itemsets3
# Out:
#    support                           itemsets
# 0      0.6                      (Sixth Sense)
# 1      0.7                        (Gladiator)
# 2      0.6                          (Patriot)
# 3      0.5           (Sixth Sense, Gladiator)
# 4      0.4             (Sixth Sense, Patriot)
# 5      0.6               (Patriot, Gladiator)
# 6      0.4  (Sixth Sense, Gladiator, Patriot)

# %%
rules3 = association_rules(frequent_itemsets3, metric="lift", min_threshold=0.8)
rules3
# Out:
#                  antecedents               consequents  antecedent support  ...  leverage  conviction  zhangs_metric
# 0              (Sixth Sense)               (Gladiator)                 0.6  ...      0.08         1.8       0.400000
# 1                (Gladiator)             (Sixth Sense)                 0.7  ...      0.08         1.4       0.533333
# 2              (Sixth Sense)                 (Patriot)                 0.6  ...      0.04         1.2       0.250000
# 3                  (Patriot)             (Sixth Sense)                 0.6  ...      0.04         1.2       0.250000
# 4                  (Patriot)               (Gladiator)                 0.6  ...      0.18         inf       0.750000
# 5                (Gladiator)                 (Patriot)                 0.7  ...      0.18         2.8       1.000000
# 6   (Sixth Sense, Gladiator)                 (Patriot)                 0.5  ...      0.10         2.0       0.500000
# ...
